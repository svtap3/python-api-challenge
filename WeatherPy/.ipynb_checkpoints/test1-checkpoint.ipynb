# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy import stats
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []
 
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
 
# Create counters
record_count = 1
set_count = 1
 
# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
 
    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q="+city
    #city_url = url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
 
    # Add 1 to the record count
    record_count += 1
 
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
# Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
 
        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
 
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | nangomba
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | solnechnyy
# Processing Record 6 of Set 1 | paamiut
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | blankenberge
# Processing Record 10 of Set 1 | ust-kulom
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | kahului
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | camalu
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | souillac
# Processing Record 18 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | longyearbyen
# Processing Record 23 of Set 1 | opuwo
# Processing Record 24 of Set 1 | kimry
# Processing Record 25 of Set 1 | portland
# Processing Record 26 of Set 1 | nanortalik
# Processing Record 27 of Set 1 | sorland
# Processing Record 28 of Set 1 | gat
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | santa ana
# Processing Record 31 of Set 1 | hamilton
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | talcahuano
# Processing Record 34 of Set 1 | trapani
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | meulaboh
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | ambon
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | malakal
# Processing Record 42 of Set 1 | trairi
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | douglas
# Processing Record 47 of Set 1 | gweta
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | agbor
# Processing Record 50 of Set 1 | ilulissat
# Processing Record 0 of Set 2 | sultanpur
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | te anau
# Processing Record 3 of Set 2 | hongjiang
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | bonfim
# Processing Record 6 of Set 2 | jimo
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | elmina
# Processing Record 10 of Set 2 | zhangjiakou
# Processing Record 11 of Set 2 | buala
# Processing Record 12 of Set 2 | rio gallegos
# Processing Record 13 of Set 2 | laguna
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | olga
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 2 | barrow
# Processing Record 21 of Set 2 | zimovniki
# Processing Record 22 of Set 2 | muroto
# Processing Record 23 of Set 2 | hobart
# Processing Record 24 of Set 2 | batemans bay
# Processing Record 25 of Set 2 | hofn
# Processing Record 26 of Set 2 | hermanus
# Processing Record 27 of Set 2 | harlingen
# Processing Record 28 of Set 2 | butaritari
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | kousseri
# Processing Record 31 of Set 2 | eyl
# Processing Record 32 of Set 2 | beringovskiy
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | vuktyl
# Processing Record 35 of Set 2 | porto de moz
# Processing Record 36 of Set 2 | paytug
# City not found. Skipping...
# Processing Record 37 of Set 2 | lengshuitan
# Processing Record 38 of Set 2 | san patricio
# Processing Record 39 of Set 2 | mount gambier
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | arman
# Processing Record 43 of Set 2 | karratha
# Processing Record 44 of Set 2 | sitka
# Processing Record 45 of Set 2 | atsiki
# City not found. Skipping...
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | stephenville
# Processing Record 48 of Set 2 | wasilla
# Processing Record 49 of Set 2 | marzuq
# Processing Record 0 of Set 3 | kasongo-lunda
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | chillan
# Processing Record 3 of Set 3 | klaksvik
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | deputatskiy
# Processing Record 6 of Set 3 | batagay
# Processing Record 7 of Set 3 | riyadh
# Processing Record 8 of Set 3 | akranes
# Processing Record 9 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 3 | winnipeg
# Processing Record 11 of Set 3 | port elizabeth
# Processing Record 12 of Set 3 | qaanaaq
# Processing Record 13 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 14 of Set 3 | kaeo
# Processing Record 15 of Set 3 | lagoa
# Processing Record 16 of Set 3 | yellowknife
# Processing Record 17 of Set 3 | zhangye
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | tiarei
# Processing Record 20 of Set 3 | vila franca do campo
# Processing Record 21 of Set 3 | okhotsk
# Processing Record 22 of Set 3 | mahajanga
# Processing Record 23 of Set 3 | avera
# Processing Record 24 of Set 3 | aleksandrovskoye
# Processing Record 25 of Set 3 | aiani
# Processing Record 26 of Set 3 | ribeira grande
# Processing Record 27 of Set 3 | hami
# Processing Record 28 of Set 3 | grande prairie
# Processing Record 29 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 3 | murray bridge
# Processing Record 31 of Set 3 | lunen
# Processing Record 32 of Set 3 | shetpe
# Processing Record 33 of Set 3 | idlib
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | rawson
# Processing Record 36 of Set 3 | alekseyevsk
# Processing Record 37 of Set 3 | cidreira
# Processing Record 38 of Set 3 | buraydah
# Processing Record 39 of Set 3 | tombouctou
# Processing Record 40 of Set 3 | sondrio
# Processing Record 41 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 3 | kyra
# Processing Record 43 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 3 | sola
# Processing Record 46 of Set 3 | soyo
# Processing Record 47 of Set 3 | sterling
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | atambua
# Processing Record 0 of Set 4 | mayo
# Processing Record 1 of Set 4 | vestmanna
# Processing Record 2 of Set 4 | seddon
# Processing Record 3 of Set 4 | rantoul
# Processing Record 4 of Set 4 | taoudenni
# Processing Record 5 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 4 | arcachon
# Processing Record 7 of Set 4 | saraipali
# Processing Record 8 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 4 | bethel
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | mizan teferi
# Processing Record 12 of Set 4 | okha
# Processing Record 13 of Set 4 | luderitz
# Processing Record 14 of Set 4 | namibe
# Processing Record 15 of Set 4 | bluff
# Processing Record 16 of Set 4 | kumo
# Processing Record 17 of Set 4 | kruisfontein
# Processing Record 18 of Set 4 | manakara
# Processing Record 19 of Set 4 | smithers
# Processing Record 20 of Set 4 | dianopolis
# City not found. Skipping...
# Processing Record 21 of Set 4 | bathsheba
# Processing Record 22 of Set 4 | alofi
# Processing Record 23 of Set 4 | taltal
# Processing Record 24 of Set 4 | jinchang
# Processing Record 25 of Set 4 | hithadhoo
# Processing Record 26 of Set 4 | yumen
# Processing Record 27 of Set 4 | pangnirtung
# Processing Record 28 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 4 | bilma
# Processing Record 30 of Set 4 | puerto escondido
# Processing Record 31 of Set 4 | veraval
# Processing Record 32 of Set 4 | manga
# Processing Record 33 of Set 4 | ahipara
# Processing Record 34 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 4 | upernavik
# Processing Record 36 of Set 4 | jidong
# Processing Record 37 of Set 4 | kavaratti
# Processing Record 38 of Set 4 | les cayes
# Processing Record 39 of Set 4 | anzhero-sudzhensk
# Processing Record 40 of Set 4 | la ronge
# Processing Record 41 of Set 4 | thompson
# Processing Record 42 of Set 4 | fortuna
# Processing Record 43 of Set 4 | tiksi
# Processing Record 44 of Set 4 | castro
# Processing Record 45 of Set 4 | tarakan
# Processing Record 46 of Set 4 | haines junction
# Processing Record 47 of Set 4 | coahuayana
# Processing Record 48 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 4 | alcanede
# Processing Record 0 of Set 5 | tartagal
# Processing Record 1 of Set 5 | basyanovskiy
# City not found. Skipping...
# Processing Record 2 of Set 5 | san anselmo
# Processing Record 3 of Set 5 | san juan
# Processing Record 4 of Set 5 | ponta do sol
# Processing Record 5 of Set 5 | novikovo
# Processing Record 6 of Set 5 | pop
# Processing Record 7 of Set 5 | honiara
# Processing Record 8 of Set 5 | zhigansk
# Processing Record 9 of Set 5 | khudumelapye
# Processing Record 10 of Set 5 | atasu
# Processing Record 11 of Set 5 | sioux lookout
# Processing Record 12 of Set 5 | san cristobal
# Processing Record 13 of Set 5 | norman wells
# Processing Record 14 of Set 5 | east london
# Processing Record 15 of Set 5 | mae sai
# Processing Record 16 of Set 5 | ostrovnoy
# Processing Record 17 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 18 of Set 5 | ust-kuyga
# Processing Record 19 of Set 5 | fort nelson
# Processing Record 20 of Set 5 | port lincoln
# Processing Record 21 of Set 5 | narsaq
# Processing Record 22 of Set 5 | homer
# Processing Record 23 of Set 5 | laukaa
# Processing Record 24 of Set 5 | saskylakh
# Processing Record 25 of Set 5 | lavrentiya
# Processing Record 26 of Set 5 | zakamensk
# Processing Record 27 of Set 5 | kalmunai
# Processing Record 28 of Set 5 | guerrero negro
# Processing Record 29 of Set 5 | marsh harbour
# Processing Record 30 of Set 5 | trussville
# Processing Record 31 of Set 5 | talara
# Processing Record 32 of Set 5 | rampur hat
# Processing Record 33 of Set 5 | shimoni
# Processing Record 34 of Set 5 | clarence town
# Processing Record 35 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 5 | unity
# Processing Record 37 of Set 5 | tasiilaq
# Processing Record 38 of Set 5 | morena
# Processing Record 39 of Set 5 | tanete
# Processing Record 40 of Set 5 | cabedelo
# Processing Record 41 of Set 5 | naryan-mar
# Processing Record 42 of Set 5 | atherton
# Processing Record 43 of Set 5 | pemex
# Processing Record 44 of Set 5 | sapanta
# Processing Record 45 of Set 5 | kargopol
# Processing Record 46 of Set 5 | esperance
# Processing Record 47 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 5 | haimen
# Processing Record 49 of Set 5 | mvuma
# Processing Record 0 of Set 6 | saldanha
# Processing Record 1 of Set 6 | mizdah
# Processing Record 2 of Set 6 | benguela
# Processing Record 3 of Set 6 | san jose
# Processing Record 4 of Set 6 | yazykovo
# Processing Record 5 of Set 6 | harper
# Processing Record 6 of Set 6 | kohlu
# Processing Record 7 of Set 6 | anadyr
# Processing Record 8 of Set 6 | dikson
# Processing Record 9 of Set 6 | iqaluit
# Processing Record 10 of Set 6 | williston
# Processing Record 11 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 6 | devonport
# Processing Record 13 of Set 6 | katunayaka
# Processing Record 14 of Set 6 | huarmey
# Processing Record 15 of Set 6 | jacareacanga
# Processing Record 16 of Set 6 | college
# Processing Record 17 of Set 6 | cabo san lucas
# Processing Record 18 of Set 6 | asau
# Processing Record 19 of Set 6 | wanning
# Processing Record 20 of Set 6 | moose factory
# Processing Record 21 of Set 6 | zhezkazgan
# Processing Record 22 of Set 6 | mount isa
# Processing Record 23 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 6 | honningsvag
# Processing Record 25 of Set 6 | artyshta
# Processing Record 26 of Set 6 | dengzhou
# Processing Record 27 of Set 6 | inuvik
# Processing Record 28 of Set 6 | khatassy
# Processing Record 29 of Set 6 | tuatapere
# Processing Record 30 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 6 | talakan
# Processing Record 32 of Set 6 | alice springs
# Processing Record 33 of Set 6 | pirot
# Processing Record 34 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 6 | quatre cocos
# Processing Record 36 of Set 6 | dingle
# Processing Record 37 of Set 6 | chifeng
# Processing Record 38 of Set 6 | bengkulu
# Processing Record 39 of Set 6 | pimentel
# Processing Record 40 of Set 6 | ojinaga
# Processing Record 41 of Set 6 | pevek
# Processing Record 42 of Set 6 | oranjemund
# Processing Record 43 of Set 6 | svetlyy
# Processing Record 44 of Set 6 | kangaatsiaq
# Processing Record 45 of Set 6 | waddan
# Processing Record 46 of Set 6 | prince rupert
# Processing Record 47 of Set 6 | codrington
# Processing Record 48 of Set 6 | port hardy
# Processing Record 49 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 0 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 7 | barcelos
# Processing Record 2 of Set 7 | talnakh
# Processing Record 3 of Set 7 | neryungri
# Processing Record 4 of Set 7 | krasnoselkup
# Processing Record 5 of Set 7 | abeche
# Processing Record 6 of Set 7 | chunskiy
# Processing Record 7 of Set 7 | belyy yar
# Processing Record 8 of Set 7 | palasa
# Processing Record 9 of Set 7 | clyde river
# Processing Record 10 of Set 7 | rancho palos verdes
# Processing Record 11 of Set 7 | hambantota
# Processing Record 12 of Set 7 | miquelon
# Processing Record 13 of Set 7 | margate
# Processing Record 14 of Set 7 | vazante
# Processing Record 15 of Set 7 | minsk
# Processing Record 16 of Set 7 | lorengau
# Processing Record 17 of Set 7 | liverpool
# Processing Record 18 of Set 7 | aklavik
# Processing Record 19 of Set 7 | north bend
# Processing Record 20 of Set 7 | pacific grove
# Processing Record 21 of Set 7 | angoram
# Processing Record 22 of Set 7 | brae
# Processing Record 23 of Set 7 | isangel
# Processing Record 24 of Set 7 | amboise
# Processing Record 25 of Set 7 | nanchang
# Processing Record 26 of Set 7 | henties bay
# Processing Record 27 of Set 7 | atar
# Processing Record 28 of Set 7 | ibra
# Processing Record 29 of Set 7 | grand gaube
# Processing Record 30 of Set 7 | cherskiy
# Processing Record 31 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 7 | mitu
# Processing Record 33 of Set 7 | bardsir
# Processing Record 34 of Set 7 | vostok
# Processing Record 35 of Set 7 | tynset
# Processing Record 36 of Set 7 | lompoc
# Processing Record 37 of Set 7 | maceio
# Processing Record 38 of Set 7 | phra phutthabat
# Processing Record 39 of Set 7 | mahibadhoo
# Processing Record 40 of Set 7 | prainha
# Processing Record 41 of Set 7 | geraldton
# Processing Record 42 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 7 | evensk
# Processing Record 44 of Set 7 | hirara
# Processing Record 45 of Set 7 | alexandria
# Processing Record 46 of Set 7 | rio grande
# Processing Record 47 of Set 7 | peniche
# Processing Record 48 of Set 7 | severnyy
# Processing Record 49 of Set 7 | bentiu
# Processing Record 0 of Set 8 | lisakovsk
# Processing Record 1 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 8 | bandarbeyla
# Processing Record 3 of Set 8 | pisco
# Processing Record 4 of Set 8 | sao felix do xingu
# Processing Record 5 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 6 of Set 8 | christchurch
# Processing Record 7 of Set 8 | kualakapuas
# Processing Record 8 of Set 8 | hendersonville
# Processing Record 9 of Set 8 | vila
# Processing Record 10 of Set 8 | muros
# Processing Record 11 of Set 8 | ust-nera
# Processing Record 12 of Set 8 | biu
# Processing Record 13 of Set 8 | araouane
# Processing Record 14 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 8 | sur
# Processing Record 16 of Set 8 | alice town
# Processing Record 17 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 18 of Set 8 | gizo
# Processing Record 19 of Set 8 | akdepe
# Processing Record 20 of Set 8 | el paso
# Processing Record 21 of Set 8 | maragogi
# Processing Record 22 of Set 8 | salamiyah
# Processing Record 23 of Set 8 | turbat
# Processing Record 24 of Set 8 | mayor pablo lagerenza
# Processing Record 25 of Set 8 | teguise
# Processing Record 26 of Set 8 | santiago
# Processing Record 27 of Set 8 | belovo
# Processing Record 28 of Set 8 | enshi
# Processing Record 29 of Set 8 | ust-kut
# Processing Record 30 of Set 8 | caravelas
# Processing Record 31 of Set 8 | kaya
# Processing Record 32 of Set 8 | broome
# Processing Record 33 of Set 8 | abu samrah
# Processing Record 34 of Set 8 | atikokan
# Processing Record 35 of Set 8 | virginia beach
# Processing Record 36 of Set 8 | sao joao da barra
# Processing Record 37 of Set 8 | totness
# Processing Record 38 of Set 8 | the valley
# Processing Record 39 of Set 8 | nizwa
# Processing Record 40 of Set 8 | angoche
# Processing Record 41 of Set 8 | chapais
# Processing Record 42 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 8 | morehead
# Processing Record 44 of Set 8 | bose
# Processing Record 45 of Set 8 | hasaki
# Processing Record 46 of Set 8 | kiunga
# Processing Record 47 of Set 8 | nioro
# Processing Record 48 of Set 8 | novyy svit
# Processing Record 49 of Set 8 | ken caryl
# Processing Record 0 of Set 9 | fare
# Processing Record 1 of Set 9 | kalinagar
# Processing Record 2 of Set 9 | lanzhou
# Processing Record 3 of Set 9 | lexington
# Processing Record 4 of Set 9 | esmeraldas
# Processing Record 5 of Set 9 | hit
# Processing Record 6 of Set 9 | leshukonskoye
# Processing Record 7 of Set 9 | stolin
# Processing Record 8 of Set 9 | whitehorse
# Processing Record 9 of Set 9 | aquidauana
# Processing Record 10 of Set 9 | constitucion
# Processing Record 11 of Set 9 | vanimo
# Processing Record 12 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 13 of Set 9 | nobeoka
# Processing Record 14 of Set 9 | manokwari
# Processing Record 15 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 16 of Set 9 | tartus
# Processing Record 17 of Set 9 | uruzgan
# Processing Record 18 of Set 9 | xai-xai
# Processing Record 19 of Set 9 | seybaplaya
# Processing Record 20 of Set 9 | mogocha
# Processing Record 21 of Set 9 | annau
# Processing Record 22 of Set 9 | sistranda
# Processing Record 23 of Set 9 | kokstad
# Processing Record 24 of Set 9 | katsuura
# Processing Record 25 of Set 9 | mogadishu
# Processing Record 26 of Set 9 | neiafu
# Processing Record 27 of Set 9 | xining
# Processing Record 28 of Set 9 | mar del plata
# Processing Record 29 of Set 9 | leh
# Processing Record 30 of Set 9 | shimoda
# Processing Record 31 of Set 9 | olafsvik
# Processing Record 32 of Set 9 | wanaka
# Processing Record 33 of Set 9 | halifax
# Processing Record 34 of Set 9 | bongandanga
# Processing Record 35 of Set 9 | mao
# Processing Record 36 of Set 9 | itirucu
# Processing Record 37 of Set 9 | rocha
# Processing Record 38 of Set 9 | hammond
# Processing Record 39 of Set 9 | touros
# Processing Record 40 of Set 9 | saint george
# Processing Record 41 of Set 9 | balikpapan
# Processing Record 42 of Set 9 | kiama
# Processing Record 43 of Set 9 | akyab
# Processing Record 44 of Set 9 | haliyal
# Processing Record 45 of Set 9 | lipin bor
# Processing Record 46 of Set 9 | jiujiang
# Processing Record 47 of Set 9 | kununurra
# Processing Record 48 of Set 9 | teahupoo
# Processing Record 49 of Set 9 | krasnyy chikoy
# Processing Record 0 of Set 10 | emerald
# Processing Record 1 of Set 10 | aasiaat
# Processing Record 2 of Set 10 | daye
# Processing Record 3 of Set 10 | krasnyy yar
# Processing Record 4 of Set 10 | gamba
# Processing Record 5 of Set 10 | kushima
# Processing Record 6 of Set 10 | saint-augustin
# Processing Record 7 of Set 10 | kita
# Processing Record 8 of Set 10 | eureka
# Processing Record 9 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 10 | shache
# Processing Record 11 of Set 10 | gazojak
# Processing Record 12 of Set 10 | mujiayingzi
# Processing Record 13 of Set 10 | cornwall
# Processing Record 14 of Set 10 | half moon bay
# Processing Record 15 of Set 10 | jalu
# Processing Record 16 of Set 10 | kaitangata
# Processing Record 17 of Set 10 | quthing
# Processing Record 18 of Set 10 | beloha
# Processing Record 19 of Set 10 | yingshang
# City not found. Skipping...
# Processing Record 20 of Set 10 | kaitong
# Processing Record 21 of Set 10 | maputo
# Processing Record 22 of Set 10 | pyinmana
# Processing Record 23 of Set 10 | nantucket
# Processing Record 24 of Set 10 | baturite
# Processing Record 25 of Set 10 | mitsamiouli
# Processing Record 26 of Set 10 | aksu
# Processing Record 27 of Set 10 | janesville
# Processing Record 28 of Set 10 | krasnyy mayak
# City not found. Skipping...
# Processing Record 29 of Set 10 | amga
# Processing Record 30 of Set 10 | nemuro
# Processing Record 31 of Set 10 | havre
# Processing Record 32 of Set 10 | kristinehamn
# Processing Record 33 of Set 10 | sao lourenco do sul
# Processing Record 34 of Set 10 | khandagayty
# Processing Record 35 of Set 10 | san ramon
# Processing Record 36 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 10 | husavik
# Processing Record 38 of Set 10 | yuli
# Processing Record 39 of Set 10 | mount pleasant
# Processing Record 40 of Set 10 | ancud
# Processing Record 41 of Set 10 | koslan
# Processing Record 42 of Set 10 | cayenne
# Processing Record 43 of Set 10 | olinda
# Processing Record 44 of Set 10 | balkhash
# Processing Record 45 of Set 10 | mathbaria
# Processing Record 46 of Set 10 | nabire
# Processing Record 47 of Set 10 | katobu
# Processing Record 48 of Set 10 | luangwa
# Processing Record 49 of Set 10 | sokode
# Processing Record 0 of Set 11 | mareeba
# Processing Record 1 of Set 11 | camana
# Processing Record 2 of Set 11 | korla
# Processing Record 3 of Set 11 | calvinia
# Processing Record 4 of Set 11 | kargil
# Processing Record 5 of Set 11 | pangkalanbuun
# Processing Record 6 of Set 11 | rudnichnyy
# Processing Record 7 of Set 11 | khandyga
# Processing Record 8 of Set 11 | aksha
# Processing Record 9 of Set 11 | carutapera
# Processing Record 10 of Set 11 | gravdal
# Processing Record 11 of Set 11 | morwell
# Processing Record 12 of Set 11 | drumheller
# Processing Record 13 of Set 11 | newport
# Processing Record 14 of Set 11 | gannan
# Processing Record 15 of Set 11 | shelburne
# Processing Record 16 of Set 11 | tsabong
# Processing Record 17 of Set 11 | bonthe
# Processing Record 18 of Set 11 | bucak
# Processing Record 19 of Set 11 | nome
# Processing Record 20 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 11 | brigantine
# Processing Record 22 of Set 11 | normandin
# Processing Record 23 of Set 11 | belmonte
# Processing Record 24 of Set 11 | yulara
# Processing Record 25 of Set 11 | lata
# Processing Record 26 of Set 11 | lebanon
# Processing Record 27 of Set 11 | sovetskiy
# Processing Record 28 of Set 11 | ziarat
# Processing Record 29 of Set 11 | naze
# Processing Record 30 of Set 11 | muli
# Processing Record 31 of Set 11 | methoni
# Processing Record 32 of Set 11 | bull savanna
# Processing Record 33 of Set 11 | meadow lake
# Processing Record 34 of Set 11 | skutec
# Processing Record 35 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 36 of Set 11 | coihaique
# Processing Record 37 of Set 11 | malanje
# Processing Record 38 of Set 11 | francisco beltrao
# Processing Record 39 of Set 11 | mehamn
# Processing Record 40 of Set 11 | skerries
# Processing Record 41 of Set 11 | garm
# City not found. Skipping...
# Processing Record 42 of Set 11 | thunder bay
# Processing Record 43 of Set 11 | carauari
# Processing Record 44 of Set 11 | san joaquin
# Processing Record 45 of Set 11 | kuldur
# Processing Record 46 of Set 11 | santa vitoria do palmar
# Processing Record 47 of Set 11 | hualmay
# Processing Record 48 of Set 11 | kakamega
# Processing Record 49 of Set 11 | makakilo city
# Processing Record 0 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 12 | seevetal
# Processing Record 2 of Set 12 | contadero
# Processing Record 3 of Set 12 | belaya gora
# Processing Record 4 of Set 12 | sikonge
# Processing Record 5 of Set 12 | farafangana
# Processing Record 6 of Set 12 | lagunas
# Processing Record 7 of Set 12 | rabo de peixe
# Processing Record 8 of Set 12 | saint anthony
# Processing Record 9 of Set 12 | sao miguel do tapuio
# Processing Record 10 of Set 12 | almeirim
# Processing Record 11 of Set 12 | batsfjord
# Processing Record 12 of Set 12 | san quintin
# Processing Record 13 of Set 12 | thinadhoo
# Processing Record 14 of Set 12 | jumla
# Processing Record 15 of Set 12 | fairbanks
# Processing Record 16 of Set 12 | moron
# Processing Record 17 of Set 12 | rosarito
# Processing Record 18 of Set 12 | salalah
# Processing Record 19 of Set 12 | athabasca
# Processing Record 20 of Set 12 | kodra
# Processing Record 21 of Set 12 | mackay
# Processing Record 22 of Set 12 | sudak
# Processing Record 23 of Set 12 | tubuala
# Processing Record 24 of Set 12 | montague
# Processing Record 25 of Set 12 | sisimiut
# Processing Record 26 of Set 12 | pokhara
# Processing Record 27 of Set 12 | mendi
# Processing Record 28 of Set 12 | praia da vitoria
# Processing Record 29 of Set 12 | obo
# Processing Record 30 of Set 12 | vila velha
# Processing Record 31 of Set 12 | jatai
# Processing Record 32 of Set 12 | santa maria
# Processing Record 33 of Set 12 | padang
# Processing Record 34 of Set 12 | chongwe
# Processing Record 35 of Set 12 | conceicao da barra
# Processing Record 36 of Set 12 | murchison
# Processing Record 37 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 12 | wewak
# Processing Record 39 of Set 12 | port blair
# Processing Record 40 of Set 12 | ghorawal
# Processing Record 41 of Set 12 | kikwit
# Processing Record 42 of Set 12 | kanigiri
# Processing Record 43 of Set 12 | necochea
# Processing Record 44 of Set 12 | shingu
# Processing Record 45 of Set 12 | smirnykh
# Processing Record 46 of Set 12 | gainesville
# Processing Record 47 of Set 12 | port macquarie
# Processing Record 48 of Set 12 | chicama
# Processing Record 49 of Set 12 | khrebtovaya
# Processing Record 0 of Set 13 | itarema
# Processing Record 1 of Set 13 | tigil
# Processing Record 2 of Set 13 | aylesbury
# Processing Record 3 of Set 13 | ovalle
# Processing Record 4 of Set 13 | zhongshu
# Processing Record 5 of Set 13 | puerto madryn
# Processing Record 6 of Set 13 | tevriz
# Processing Record 7 of Set 13 | boone
# Processing Record 8 of Set 13 | saint-francois
# Processing Record 9 of Set 13 | antalaha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.count()
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Country       564
# Date          564
# dtype: int64

# %%
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        vaini -21.2000 -175.2000     28.09        74          40        5.14
# 1    carnarvon -24.8667  113.6333     21.01        77           0        7.65
# 2     nangomba -10.9000   38.5000     22.43        76           6        3.09
# 3  new norfolk -42.7826  147.0587     14.95        47          14        1.39
# 4   solnechnyy  50.7214  136.6319     -2.57        50         100        1.30
#
#   Country        Date
# 0      TO  1667516278
# 1      AU  1667515956
# 2      TZ  1667516279
# 3      AU  1667516280
# 4      RU  1667516280

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 564 entries, 0 to 563
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        564 non-null    object
#  1   Lat         564 non-null    float64
#  2   Lng         564 non-null    float64
#  3   Max Temp    564 non-null    float64
#  4   Humidity    564 non-null    int64
#  5   Cloudiness  564 non-null    int64
#  6   Wind Speed  564 non-null    float64
#  7   Country     564 non-null    object
#  8   Date        564 non-null    int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 39.8+ KB

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              vaini -21.2000 -175.2000     28.09        74          40
# 1          carnarvon -24.8667  113.6333     21.01        77           0
# 2           nangomba -10.9000   38.5000     22.43        76           6
# 3        new norfolk -42.7826  147.0587     14.95        47          14
# 4         solnechnyy  50.7214  136.6319     -2.57        50         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      TO  1667516278
# 1              7.65      AU  1667515956
# 2              3.09      TZ  1667516279
# 3              1.39      AU  1667516280
# 4              1.30      RU  1667516280

# %%
lat_temp = city_data_df
lat_temp
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 vaini -21.2000 -175.2000     28.09        74          40
# 1             carnarvon -24.8667  113.6333     21.01        77           0
# 2              nangomba -10.9000   38.5000     22.43        76           6
# 3           new norfolk -42.7826  147.0587     14.95        47          14
# 4            solnechnyy  50.7214  136.6319     -2.57        50         100
# ...                 ...      ...       ...       ...       ...         ...
# 559       puerto madryn -42.7692  -65.0385     21.05        33           0
# 560              tevriz  57.5090   72.4042      0.33        90          92
# 561               boone  39.0334  -92.3335     25.14        62          46
# 562      saint-francois  46.4154    3.9054      9.69        81           0
# 563            antalaha -14.9003   50.2788     20.86        85          52
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      TO  1667516278
# 1              7.65      AU  1667515956
# 2              3.09      TZ  1667516279
# 3              1.39      AU  1667516280
# 4              1.30      RU  1667516280
# ...             ...     ...         ...
# 559            9.14      AR  1667516570
# 560            2.95      RU  1667516570
# 561            6.12      US  1667516570
# 562            3.09      FR  1667516011
# 563            1.03      MG  1667516571
#
# [564 rows x 9 columns]

# %%
# Build scatter plot for latitude vs. temperature

#Markersize
sizes = [50]

lat_temp.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(10,6), marker = "o", sizes = sizes, c = "blue", edgecolors="black") 

plt.title(f"City Max Latitude vs Max Temperature ({datetime.now():%y-%m-%d})")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build scatter plot for latitude vs. Humidity

#Markersize
sizes = [50]

lat_temp.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(10,6), marker = "o", sizes=sizes, c="blue", edgecolors='black')

plt.title(f"Latitude vs Max Humidity ({datetime.now():%y-%m-%d})")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build scatter plot for latitude vs. Cloudiness

#Markersize
sizes = [50]

lat_temp.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(10,6), marker = "o", sizes =sizes, c="blue", edgecolors='black')

plt.title(f"Latitude vs Cloudiness ({datetime.now():%y-%m-%d})")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build scatter plot for latitude vs. Wind Speed

#Markersize
sizes = [50]

lat_temp.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(10,6), marker = "o", sizes=sizes, c="blue", edgecolors='black')

plt.title(f"Latitude vs Wind Speed ({datetime.now():%y-%m-%d})")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
north_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0,:]
north_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4          solnechnyy  50.7214  136.6319     -2.57        50         100
# 5             paamiut  61.9940  -49.6678      2.17        89         100
# 7              kodiak  57.7900 -152.4072      2.35        59           1
# 8        blankenberge  51.3131    3.1323     11.08        85          71
# 9           ust-kulom  61.6864   53.6902     -2.07        94         100
#
#          Wind Speed Country        Date
# City_ID
# 4              1.30      RU  1667516280
# 5              2.88      GL  1667516280
# 7              3.92      US  1667516281
# 8              4.57      BE  1667516281
# 9              2.27      RU  1667516282

# %%
x_values_north_lat = north_hemi_df['Lat']
y_values_north_temp = north_hemi_df['Max Temp']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_north_lat, y_values_north_temp)

# Get regression values
regress_values_north_temp = x_values_north_lat * slope + intercept
print(regress_values_north_temp)
# Out:
# City_ID
# 4       3.856443
# 5      -2.688143
# 7      -0.247407
# 8       3.512917
# 9      -2.509558
#          ...
# 556     3.220539
# 558    19.070227
# 560    -0.084266
# 561    10.642199
# 562     6.356397
# Name: Lat, Length: 383, dtype: float64

# %%
# Create line equation string
line_eq_north_temp = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq_north_temp)
# Out:
# y = -0.58x +33.3

# %% [markdown]
# # Northern Hemisphere: Temperature vs. Latitude

# %%
# Create Plot
plt.scatter(x_values_north_lat,y_values_north_temp)
plt.plot(x_values_north_lat,regress_values_north_temp,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(40,30),fontsize=15,color="green")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.6853783487961657

# %%
south_hemi_df = city_data_df.loc[city_data_df["Lat"]<0,:]
south_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               vaini -21.2000 -175.2000     28.09        74          40
# 1           carnarvon -24.8667  113.6333     21.01        77           0
# 2            nangomba -10.9000   38.5000     22.43        76           6
# 3         new norfolk -42.7826  147.0587     14.95        47          14
# 6        punta arenas -53.1500  -70.9167     17.06        63          40
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      TO  1667516278
# 1              7.65      AU  1667515956
# 2              3.09      TZ  1667516279
# 3              1.39      AU  1667516280
# 6             10.29      CL  1667515635

# %%
x_values_south_lat = south_hemi_df['Lat']
y_values_south_temp = south_hemi_df['Max Temp']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_south_lat, y_values_south_temp)

# Get regression values
regress_values_south_temp = x_values_south_lat * slope + intercept
print(regress_values_south_temp)
# Out:
# City_ID
# 0      20.881072
# 1      19.979063
# 2      23.414874
# 3      15.571749
# 6      13.021367
#          ...
# 552    24.166478
# 554    25.376774
# 557    18.569089
# 559    15.575045
# 563    22.430799
# Name: Lat, Length: 181, dtype: float64

# %%
# Create line equation string
line_eq_south_temp = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq_south_temp)
# Out:
# y = 0.25x +26.1

# %% [markdown]
# # Southern Hemisphere: Temperature vs. Latitude

# %%
plt.scatter(x_values_south_lat,y_values_south_temp)
plt.plot(x_values_south_lat,regress_values_south_temp,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq_south_temp,(40,30),fontsize=15,color="green")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.4438903173496634

# %%
x_values_north_lat = north_hemi_df['Lat']
y_values_north_hum = north_hemi_df['Humidity']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_north_lat, y_values_north_hum)

# Get regression values
regress_values_north_hum = x_values_north_lat * slope + intercept
print(regress_values_north_hum)
# Out:
# City_ID
# 4      76.295369
# 5      79.973215
# 7      78.601600
# 8      76.488420
# 9      79.872856
#          ...
# 556    76.652726
# 558    67.745714
# 560    78.509920
# 561    72.481993
# 562    74.890476
# Name: Lat, Length: 383, dtype: float64

# %%
# Create line equation string
line_eq_north_hum = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq_north_hum)
# Out:
# y = 0.33x +59.75

# %% [markdown]
# # Northern Hemisphere: Humidity vs. Latitude

# %%
# Create Plot
plt.scatter(x_values_north_lat,y_values_north_hum)
plt.plot(x_values_north_lat,regress_values_north_hum,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(40,10),fontsize=15,color="green")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.09004953669030635

# %%
x_values_south_lat = south_hemi_df['Lat']
y_values_south_hum = south_hemi_df['Humidity']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values_south_lat, y_values_south_hum)

# Get regression values
regress_values_south_hum = x_values_south_lat * slope + intercept
print(regress_values_south_hum)
# Out:
# City_ID
# 0      72.987014
# 1      71.682333
# 2      76.651946
# 3      65.307522
# 6      61.618607
#          ...
# 552    77.739079
# 554    79.489671
# 557    69.642923
# 559    65.312290
# 563    75.228564
# Name: Lat, Length: 181, dtype: float64

# %%
# Create line equation string
line_eq_south_hum = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq_south_hum)
# Out:
# y = 0.36x +80.53

# %% [markdown]
# # Southern Hemisphere: Humidity vs. Latitude

# %%
plt.scatter(x_values_south_lat,y_values_south_hum)
plt.plot(x_values_south_lat,regress_values_south_hum,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq_south_hum,(40,10),fontsize=15,color="green")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.07357984406382773
